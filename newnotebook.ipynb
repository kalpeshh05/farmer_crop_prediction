# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("farmer.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
group= df.groupby('label')
group

# %%
group[['N']].mean()
# Out:
#                   N
# label
# apple         20.80
# banana       100.23
# blackgram     40.02
# chickpea      40.09
# coconut       21.98
# coffee       101.20
# cotton       117.77
# grapes        23.18
# jute          78.40
# kidneybeans   20.75
# lentil        18.77
# maize         77.76
# mango         20.07
# mothbeans     21.44
# mungbean      20.99
# muskmelon    100.32
# orange        19.58
# papaya        49.88
# pigeonpeas    20.73
# pomegranate   18.87
# rice          79.89
# watermelon    99.42

# %%
group[['temperature']].mean()
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
group[['N']].min()
# Out:
#                N
# label
# apple          0
# banana        80
# blackgram     20
# chickpea      20
# coconut        0
# coffee        80
# cotton       100
# grapes         0
# jute          60
# kidneybeans    0
# lentil         0
# maize         60
# mango          0
# mothbeans      0
# mungbean       0
# muskmelon     80
# orange         0
# papaya        31
# pigeonpeas     0
# pomegranate    0
# rice          60
# watermelon    80

# %%
group[['N']].max()
# Out:
#                N
# label
# apple         40
# banana       120
# blackgram     60
# chickpea      60
# coconut       40
# coffee       120
# cotton       140
# grapes        40
# jute         100
# kidneybeans   40
# lentil        40
# maize        100
# mango         40
# mothbeans     40
# mungbean      40
# muskmelon    120
# orange        40
# papaya        70
# pigeonpeas    40
# pomegranate   40
# rice          99
# watermelon   120

# %%
result = group[['temperature']].agg(['mean', 'min', 'max'])
print(result)
# Out:
#             temperature
#                    mean        min        max
# label
# apple         22.630942  21.036527  23.996862
# banana        27.376798  25.010185  29.908885
# blackgram     29.973340  25.097374  34.946616
# chickpea      18.872847  17.024985  20.995022
# coconut       27.409892  25.008724  29.869083
# coffee        25.540477  23.059519  27.923744
# cotton        23.988958  22.000851  25.992374
# grapes        23.849575   8.825675  41.948657
# jute          24.958376  23.094338  26.985822
# kidneybeans   20.115085  15.330426  24.923601
# lentil        24.509052  18.064861  29.944139
# maize         22.389204  18.041855  26.549864
# mango         31.208770  27.003155  35.990097
# mothbeans     28.194920  24.018254  31.999286
# mungbean      28.525775  27.014704  29.914544
# muskmelon     28.663066  27.024151  29.943492
# orange        22.765725  10.010813  34.906653
# papaya        33.723859  23.012402  43.675493
# pigeonpeas    27.741762  18.319104  36.977944
# ...

# %%
plt.barh(result.index, result[('temperature', 'max')], color='dodgerblue')
plt.xlabel('Max Temperature')
plt.ylabel('Labels')
plt.title('Max Temperature by Label')
plt.show()

# %%
plt.barh(result.index, result[('temperature', 'mean')], color='red')
plt.ylabel('Max Temperature')
plt.xlabel('Labels')
plt.title('Max Temperature by Label')
plt.show()

# %%
plt.barh(result.index, result[('temperature', 'max')], color='yellow')
plt.xlabel('Max Temperature')
plt.ylabel('Labels')
plt.title('Max Temperature by Label')
plt.show()

# %%
result.index
# Out:
# Index(['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee',
#        'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize', 'mango',
#        'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya', 'pigeonpeas',
#        'pomegranate', 'rice', 'watermelon'],
#       dtype='object', name='label')

# %%
min_temperature = group['temperature'].mean()
min_temperature.plot.bar(color='crimson')

plt.xlabel('Label')
plt.ylabel('Avg Temperature')
plt.title('Avg Temperature by Label')

plt.show()

# %%
max_temperature = group['temperature'].mean()
max_temperature.plot.bar(color='blue')

plt.xlabel('Label')
plt.ylabel('Avg Temperature')
plt.title('Avg Temperature by Label')

plt.show()

# %%
mean_temperature = group['temperature'].mean()
mean_temperature.plot.bar(color='yellow')

plt.xlabel('Label')
plt.ylabel('Avg Temperature')
plt.title('Avg Temperature by Label')

plt.show()

# %%
mean_temperature = group['temperature'].mean()

# Plotting the pie chart
mean_temperature.plot.pie(autopct='%1.1f%%', colors=['yellow', 'lightgreen', 'lightblue', 'orange', 'pink'])

plt.ylabel('')  # Removing the y-label as it's not needed for a pie chart
plt.title('Avg Temperature by Label')
plt.show()

# %%
x= df.drop('label',axis='columns')
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
x.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
x.duplicated().sum()
# Out:
# 0

# %%
x.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# dtype: object

# %%
sns.kdeplot(x['temperature'])  #we use this plot to check distribution plot
# Out:
# <Axes: xlabel='temperature', ylabel='Density'>

# %%
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
x_transformed= std_scaler.fit_transform(x)

# %%
x.shape
# Out:
# (2200, 7)

# %%
sns.kdeplot(pd.DataFrame(x_transformed))
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x['temperature'])
plt.show()

# %% [markdown]
# ### ready to train the algorithm

# %%
from sklearn.cluster import KMeans

# %%
Kmeans_obj = KMeans()

# %% [markdown]
# algorithm trained and prediction

# %%
labels = Kmeans_obj.fit_predict(x_transformed)

# %%
set(labels)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
labels
# Out:
# array([7, 7, 7, ..., 7, 3, 7])

# %%
df['cluster_no'] = labels

# %%
df.head(40)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label  cluster_no
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice           7
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice           7
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice           7
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice           7
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice           7
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000  rice           7
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860  rice           7
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195  rice           7
# 8   89  54  38    24.515881  83.535216  6.685346  230.446236  rice           7
# 9   68  58  38    23.223974  83.033227  6.336254  221.209196  rice           7
# 10  91  53  40    26.527235  81.417538  5.386168  264.614870  rice           7
# ...

# %%
df[df['cluster_no'] ==6]['label'].unique()
# Out:
# array(['pigeonpeas', 'mothbeans', 'lentil', 'mango'], dtype=object)

# %%
import os
import joblib

# %%
os.makedirs('models',exist_ok=True)
joblib.dump(std_scaler,'./models/std_scaler.lb')
joblib.dump(Kmeans_obj,'./models/kmeans_model.lb')
# Out:
# ['./models/kmeans_model.lb']

# %%
df[['label','cluster_no']].to_csv('./models/filter_crops.csv',index=False)
